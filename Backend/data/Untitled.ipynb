# %%
import pandas as pd
import os

new_cities_data = [
  {
    "state_name": "Jammu and Kashmir",
    "city_name": "Srinagar",
    "category": "Nature & Culture",
    "description": "Srinagar, the summer capital of Jammu and Kashmir, is famous for its Dal Lake, houseboats, Mughal gardens, and traditional Kashmiri culture.",
    "latitude": 34.0837,
    "longitude": 74.7973,
    "best_time_to_visit": "April to October",
    "popular_months": ["May", "June", "July", "August", "September"],
    "tourist_rating": 4.8,
    "risk_index": "Low",
    "photos": [
      "https://upload.wikimedia.org/wikipedia/commons/7/7d/Dal_Lake_Srinagar.jpg",
      "https://upload.wikimedia.org/wikipedia/commons/f/f3/Shikara_on_Dal_Lake.jpg"
    ],
    "top_attractions": ["Dal Lake", "Nishat Bagh", "Shalimar Bagh", "Chashme Shahi", "Shankaracharya Temple"]
  },
  {
    "state_name": "Jammu and Kashmir",
    "city_name": "Gulmarg",
    "category": "Adventure & Snow",
    "description": "Gulmarg is one of India’s premier hill stations known for its skiing slopes, meadows, and the world’s second-highest cable car ride.",
    "latitude": 34.0522,
    "longitude": 74.3805,
    "best_time_to_visit": "December to February (snow), March to June (greenery)",
    "popular_months": ["January", "February", "March", "June"],
    "tourist_rating": 4.7,
    "risk_index": "Low",
    "photos": [
      "https://upload.wikimedia.org/wikipedia/commons/4/4b/Gulmarg_Snowfields.jpg",
      "https://upload.wikimedia.org/wikipedia/commons/e/e3/Gulmarg_Gondola.jpg"
    ],
    "top_attractions": ["Gulmarg Gondola", "Khilanmarg", "Apharwat Peak", "St. Mary’s Church"]
  },
  {
    "state_name": "Jammu and Kashmir",
    "city_name": "Pahalgam",
    "category": "Valley & Adventure",
    "description": "Pahalgam is a peaceful valley along the Lidder River and serves as a base for the Amarnath Yatra. It’s known for its pine forests and beautiful valleys.",
    "latitude": 34.0150,
    "longitude": 75.3167,
    "best_time_to_visit": "March to October",
    "popular_months": ["April", "May", "June", "September"],
    "tourist_rating": 4.6,
    "risk_index": "Low",
    "photos": [
      "https://upload.wikimedia.org/wikipedia/commons/2/2d/Pahalgam_Valley.jpg",
      "https://upload.wikimedia.org/wikipedia/commons/8/89/Betab_Valley_Pahalgam.jpg"
    ],
    "top_attractions": ["Betaab Valley", "Aru Valley", "Lidder River", "Baisaran Hills"]
  },
  {
    "state_name": "Jammu and Kashmir",
    "city_name": "Sonamarg",
    "category": "Nature & Trekking",
    "description": "Sonamarg, meaning 'Meadow of Gold', is surrounded by glaciers and alpine meadows, making it a perfect destination for trekkers and nature lovers.",
    "latitude": 34.3040,
    "longitude": 75.2937,
    "best_time_to_visit": "May to October",
    "popular_months": ["June", "July", "August"],
    "tourist_rating": 4.7,
    "risk_index": "Moderate (weather dependent)",
    "photos": [
      "https://upload.wikimedia.org/wikipedia/commons/9/9e/Sonamarg_Valley.jpg",
      "https://upload.wikimedia.org/wikipedia/commons/a/aa/Thajiwas_Glacier_Sonamarg.jpg"
    ],
    "top_attractions": ["Thajiwas Glacier", "Zero Point", "Baltal Valley"]
  },
  {
    "state_name": "Jammu and Kashmir",
    "city_name": "Yusmarg",
    "category": "Nature & Offbeat",
    "description": "Yusmarg is an offbeat gem surrounded by pine forests and snow-capped mountains, ideal for short treks and nature walks.",
    "latitude": 33.8060,
    "longitude": 74.6680,
    "best_time_to_visit": "April to October",
    "popular_months": ["May", "June", "July"],
    "tourist_rating": 4.5,
    "risk_index": "Low",
    "photos": [
      "https://upload.wikimedia.org/wikipedia/commons/a/a2/Yusmarg_Meadows.jpg",
      "https://upload.wikimedia.org/wikipedia/commons/7/7e/Doodh_Ganga_River_Yusmarg.jpg"
    ],
    "top_attractions": ["Doodh Ganga River", "Nilnag Lake", "Sang-e-Safed Valley"]
  },
  {
    "state_name": "Jammu and Kashmir",
    "city_name": "Kupwara",
    "category": "Scenic & Offbeat",
    "description": "Kupwara is known for its untouched natural beauty, lush green meadows, and rich Kashmiri culture. It’s less crowded and perfect for peace seekers.",
    "latitude": 34.5313,
    "longitude": 74.2530,
    "best_time_to_visit": "May to September",
    "popular_months": ["June", "July", "August"],
    "tourist_rating": 4.4,
    "risk_index": "Moderate (border proximity)",
    "photos": [
      "https://upload.wikimedia.org/wikipedia/commons/2/27/Kupwara_Valley.jpg"
    ],
    "top_attractions": ["Bangus Valley", "Seemab Valley", "Kalaroos Caves"]
  },
  {
    "state_name": "Jammu and Kashmir",
    "city_name": "Jammu",
    "category": "Pilgrimage & Culture",
    "description": "Jammu, the winter capital, is home to many ancient temples, palaces, and cultural sites.",
    "latitude": 32.7266,
    "longitude": 74.8570,
    "best_time_to_visit": "October to March",
    "popular_months": ["November", "December", "January", "February"],
    "tourist_rating": 4.5,
    "risk_index": "Low",
    "photos": [
      "https://upload.wikimedia.org/wikipedia/commons/0/00/Raghunath_Temple_Jammu.jpg",
      "https://upload.wikimedia.org/wikipedia/commons/1/18/Jammu_City_View.jpg"
    ],
    "top_attractions": ["Raghunath Temple", "Amar Mahal Palace", "Mubarak Mandi Palace"]
  },
  {
    "state_name": "Jammu and Kashmir",
    "city_name": "Katra",
    "category": "Pilgrimage",
    "description": "Katra serves as the base for the Vaishno Devi Temple pilgrimage and attracts millions of devotees every year.",
    "latitude": 32.9914,
    "longitude": 74.9310,
    "best_time_to_visit": "March to October",
    "popular_months": ["April", "May", "September", "October"],
    "tourist_rating": 4.9,
    "risk_index": "Low",
    "photos": [
      "https://upload.wikimedia.org/wikipedia/commons/4/47/Vaishno_Devi_Bhawan.jpg",
      "https://upload.wikimedia.org/wikipedia/commons/2/28/Katra_town_view.jpg"
    ],
    "top_attractions": ["Vaishno Devi Temple", "Bhairon Temple", "Ardh Kuwari Cave"]
  },
  {
    "state_name": "Jammu and Kashmir",
    "city_name": "Patnitop",
    "category": "Hill Station & Adventure",
    "description": "Patnitop is a hill station known for its scenic beauty, paragliding, and winter snowfall.",
    "latitude": 33.0810,
    "longitude": 75.3290,
    "best_time_to_visit": "May to June and September to October",
    "popular_months": ["May", "June", "October"],
    "tourist_rating": 4.5,
    "risk_index": "Low",
    "photos": [
      "https://upload.wikimedia.org/wikipedia/commons/f/f6/Patnitop_snow.jpg",
      "https://upload.wikimedia.org/wikipedia/commons/b/bf/Patnitop_Meadows.jpg"
    ],
    "top_attractions": ["Madhatop", "Naag Temple", "Paragliding Point"]
  },
  {
    "state_name": "Jammu and Kashmir",
    "city_name": "Bhaderwah",
    "category": "Valley & Nature",
    "description": "Bhaderwah, often called 'Mini Kashmir', is known for its picturesque meadows, mountains, and rich biodiversity.",
    "latitude": 32.9800,
    "longitude": 75.7160,
    "best_time_to_visit": "April to October",
    "popular_months": ["May", "June", "September"],
    "tourist_rating": 4.6,
    "risk_index": "Low",
    "photos": [
      "https://upload.wikimedia.org/wikipedia/commons/3/3f/Bhaderwah_Valley.jpg"
    ],
    "top_attractions": ["Chinta Valley", "Padri", "Seoj Meadow"]
  },
  {
    "state_name": "Jammu and Kashmir",
    "city_name": "Mansar Lake",
    "category": "Lake & Picnic Spot",
    "description": "Mansar Lake is a serene freshwater lake near Jammu, surrounded by forests and temples.",
    "latitude": 32.7050,
    "longitude": 75.1450,
    "best_time_to_visit": "October to March",
    "popular_months": ["November", "December", "January"],
    "tourist_rating": 4.4,
    "risk_index": "Low",
    "photos": [
      "https://upload.wikimedia.org/wikipedia/commons/5/52/Mansar_Lake_Jammu.jpg"
    ],
    "top_attractions": ["Mansar Lake Temple", "Boating Point", "Wildlife Sanctuary"]
  },
  {
    "state_name": "Jammu and Kashmir",
    "city_name": "Verinag",
    "category": "Historical & Natural",
    "description": "Verinag is known for the beautiful spring that marks the source of the Jhelum River and Mughal-era gardens.",
    "latitude": 33.5550,
    "longitude": 75.2600,
    "best_time_to_visit": "April to October",
    "popular_months": ["May", "June", "September"],
    "tourist_rating": 4.5,
    "risk_index": "Low",
    "photos": [
      "https://upload.wikimedia.org/wikipedia/commons/f/f2/Verinag_Spring.jpg"
    ],
    "top_attractions": ["Verinag Spring", "Mughal Garden", "Jhelum River Origin"]
  }
]

#     # Also Manali, Dharamshala, Dalhousie, Kullu, Spiti Valley, Chamba, etc.
# ]

df_cities = pd.DataFrame(new_cities_data)

filename = "cities.csv"

if os.path.exists(filename):
    existing_df = pd.read_csv(filename)
    combined_df = pd.concat([existing_df, df_cities], ignore_index=True)
    combined_df.to_csv(filename, index=False)
else:
    df_cities.to_csv(filename, index=False)

print(f"Cities data for Goa, Gujarat, Haryana, Himachal Pradesh written to {filename}")
# Out:
# Cities data for Goa, Gujarat, Haryana, Himachal Pradesh written to cities.csv
